# %%
# Notebook 2
from notebook1 import my_function

result = my_function(5)
print(result)  # Output: 10
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_61614/573485111.py in <module>
#       1 # Notebook 2
# ----> 2 from notebook1 import my_function
#       3
#       4 result = my_function(5)
#       5 print(result)  # Output: 10
#
# ModuleNotFoundError: No module named 'notebook1'
